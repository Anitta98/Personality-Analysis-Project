# %% [markdown]
# ### Agreeableness and Neuroticism

# %%
#Agreeableness

c16=0
for i in res:
    for j in cooperation:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c16=c16+1
print(c16/len(cooperation))

c17=0
for i in res:
    for j in modesty:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c17=c17+1
print(c17/len(modesty))

c18=0
for i in res:
    for j in sympathy:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c18=c18+1
print(c18/len(sympathy))

c19=0
for i in res:
    for j in trust:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c19=c19+1
print(c19/len(trust))

c20=0
for i in res:
    for j in uncompromise:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c20=c20+1
print(c20/len(uncompromise))

c21=0
for i in res:
    for j in altruism:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c21=c21+1
print(c21/len(altruism))

#Neuroticism

c22=0
for i in res:
    for j in prone_to_worry:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c22=c22+1
print(c22/len(prone_to_worry))

c23=0
for i in res:
    for j in immoderation:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c23=c23+1
print(c23/len(immoderation))

c24=0
for i in res:
    for j in fiery:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c24=c24+1
print(c24/len(fiery))

c25=0
for i in res:
    for j in self_conscieousness:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c25=c25+1
print(c25/len(self_conscieousness))

c26=0
for i in res:
    for j in susceptible_to_stress:
        i=porter.stem(i)
        j=porter.stem(j)
        if j.lower() in i.lower():
            c26=c26+1
print(c26/len(susceptible_to_stress))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a0ce14df4be5> in <module>
#       2
#       3 c16=0
# ----> 4 for i in res:
#       5     for j in cooperation:
#       6         i=porter.stem(i)
#
# NameError: name 'res' is not defined
